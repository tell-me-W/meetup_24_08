# %% [markdown]
# # LLM 트렌드 update

# %% [markdown]
# #### LLM 의 시대에서 LMM (Large Multimodal Model)의 시대로
# - 텍스트, 이미지, 음성, 비디오
# - GPT-4o(Voice Model), Gemini-1.5 Pro
#
# #### AI의 성능 향상 (MMLU - ai의 수능)
# ![image.png](attachment:image.png)
#
# #### 경량화 (Quantization)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# https://github.com/matt-c1/llama-3-quant-comparison
#
# https://context.ai/compare/gpt-4o-mini/gpt-4o-2024-08-06

# %% [markdown]
# ### AI 에이전트 / 온디바이스 AI / 휴머노이드 로봇

# %% [markdown]
# ![AI 에이전트](attachment:image.png)
